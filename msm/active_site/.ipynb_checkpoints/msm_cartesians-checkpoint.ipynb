# %%
# %pylab inline
import pyemma.coordinates as coor
import pyemma.msm as msm
import pyemma.plots as mplt
from glob import glob
import pickle
import numpy as np
import matplotlib.pyplot as plt
import sys
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Globals

# %%
ttw = np.arange(0,45)
asp = np.arange(45,57)
groups = [ttw, asp]
topfile = 'act_site.pdb'
feat = coor.featurizer(topfile)

# %%
traj_list = glob('aligned/*as[12]-aligned.dcd')
inp = coor.source(traj_list, feat)
print('number of trajectories = ',inp.number_of_trajectories())
print('trajectory length = ',inp.trajectory_length(0))
print('trajectory time step = ',2000 / (inp.trajectory_length(0)),'ps')
# Out:
# ('number of trajectories = ', 220)
# ('trajectory length = ', 1000)
# ('trajectory time step = ', 2, 'ps')

# %% [markdown]
# ## Add cartesian coordinate features

# %%
feat.add_all()
print(inp.dimension())
print(inp.describe()[:10])
# Out:
# 171
# ['Feature reader with following features', 'ATOM:TTW 39 N 0 x', 'ATOM:TTW 39 N 0 y', 'ATOM:TTW 39 N 0 z', 'ATOM:TTW 39 HN 1 x', 'ATOM:TTW 39 HN 1 y', 'ATOM:TTW 39 HN 1 z', 'ATOM:TTW 39 CA 2 x', 'ATOM:TTW 39 CA 2 y', 'ATOM:TTW 39 CA 2 z']

# %% [markdown]
# ## TICA

# %%
matplotlib.rcParams.update({'font.size': 14})
dt = 1
figure(figsize(8,20))
tica_lags=np.arange(10,110, 10)
num = len(tica_lags)
ax1=plt.subplot(num,1,1)
for tica_lag in tica_lags:
    tica_obj = coor.tica(inp, lag=tica_lag, dim=1, kinetic_map=True)
    Y = tica_obj.get_output()
# Out:
# 16

# %%
print('TICA dimension: ', tica_obj.dimension())
print('TICA cumulative variance:')
figure(figsize(8,5))

plt.plot(tica_obj.cumvar*100)
plt.plot(np.repeat(75, 100))
plt.plot(np.repeat(90, 100))
plt.xlabel('Tica component')
plt.ylabel('Cumulative variance')
plt.xlim((0,20))
# Out:
# ('TICA dimension: ', 16)
# TICA cumulative variance:
# (0, 20)

# %%
# for i in range(171):
#     if tica_obj.eigenvectors[0, i] > 0:
#         tica_obj.eigenvectors[:, i] *= -1

# %%
Y = tica_obj.get_output() # get tica coordinates
print('number of trajectories = ', np.shape(Y)[0])
print('number of frames = ', np.shape(Y)[1])
print('number of dimensions = ',np.shape(Y)[2])
# Out:
# ('number of trajectories = ', 220)
# ('number of frames = ', 1000)
# ('number of dimensions = ', 16)

# %%
matplotlib.rcParams.update({'font.size': 14})
dt = 1
figure(figsize(8,20))
ax1=plt.subplot(16,1,1)
x = dt*np.arange(Y[0].shape[0])

for i in range(15):
    ax1=plt.subplot(16,1,i+1)
    y = Y[0][:,i] #(Y[0][:,i] - np.mean(Y[0][:,i]))/np.std(Y[0][:,i])
    plot(x, y); ylabel('IC {}'.format(i+1)); xticks([])
#     ylim((-3,3))
    
ax1=plt.subplot(16,1,16)
plot(x, Y[0][:,15]); xlabel('time / ps'); ylabel('IC 16');

# %% [markdown]
# ## Cluster

# %%
n_clusters = 250      # number of k-means clusters
clustering = coor.cluster_kmeans(Y,k=n_clusters)
# Out:
# 21-01-17 21:53:59 pyemma.coordinates.clustering.kmeans.KmeansClustering[8] INFO     Cluster centers converged after 5 steps.

# %%
dtrajs = clustering.dtrajs

# %%
figure(figsize(8,5))
i, j = 9,10
mplt.plot_free_energy(np.vstack(Y)[:,i], np.vstack(Y)[:,j])
cc_x = clustering.clustercenters[:,i]
cc_y = clustering.clustercenters[:,j]
plot(cc_x,cc_y, linewidth=0, marker='o', markersize=5, color='black')

# %% [markdown]
# ## MSM

# %%
its = msm.timescales_msm(dtrajs, lags=np.arange(100,1000,100), nits=10)

# %%
matplotlib.rcParams.update({'font.size': 14})
mplt.plot_implied_timescales(its, ylog=False, units='steps', linewidth=2)
# xlim(0, 40); ylim(0, 120);

# %%
msm_lag = 400
M = msm.estimate_markov_model(dtrajs, msm_lag)
print('fraction of states used = ', M.active_state_fraction)
print('fraction of counts used = ', M.active_count_fraction)
# Out:
# ('fraction of states used = ', 0.28)
# ('fraction of counts used = ', 0.2691409090909091)

# %%
hmm = M.coarse_grain(4)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-84-fb5a0e0a3ba4> in <module>()
# ----> 1 hmm = M.coarse_grain(4)
#
# /Users/robert_arbon/anaconda/lib/python2.7/site-packages/pyemma/msm/estimators/maximum_likelihood_msm.pyc in coarse_grain(self, ncoarse, method)
#     744             'nstates must be an int in [2,msmobj.nstates]'
#     745
# --> 746         return self.hmm(ncoarse)
#     747
#     748     ################################################################################
#
# /Users/robert_arbon/anaconda/lib/python2.7/site-packages/pyemma/msm/estimators/maximum_likelihood_msm.pyc in hmm(self, nhidden)
#     715         estimator = MaximumLikelihoodHMSM(lag=self.lagtime, nstates=nhidden, msm_init=self,
#     716                                           reversible=self.is_reversible, dt_traj=self.dt_traj)
# --> 717         estimator.estimate(self.discrete_trajectories_full)
#     718         return estimator.model
#     719
#
# /Users/robert_arbon/anaconda/lib/python2.7/site-packages/pyemma/_base/estimator.pyc in estimate(self, X, **params)
#     409         if params:
#     410             self.set_params(**params)
# --> 411         self._model = self._estimate(X)
#     412         self._estimated = True
#     413         return self
#
# /Users/robert_arbon/anaconda/lib/python2.7/site-packages/pyemma/msm/estimators/maximum_likelihood_hmsm.pyc in _estimate(self, dtrajs)
#     215                                               accuracy=self.accuracy, maxit=self.maxit)
#     216         # run
# --> 217         hmm_est.fit()
#     218         # package in discrete HMM
#     219         self.hmm = bhmm.DiscreteHMM(hmm_est.hmm)
#
# /Users/robert_arbon/anaconda/lib/python2.7/site-packages/bhmm/estimators/maximum_likelihood.pyc in fit(self)
#     386
#     387             # update model
# --> 388             self._update_model(self._gammas, self._Cs, maxiter=self._maxit_P)
#     389             t3 = time.time()
#     390
#
# /Users/robert_arbon/anaconda/lib/python2.7/site-packages/bhmm/estimators/maximum_likelihood.pyc in _update_model(self, gammas, count_matrices, maxiter)
#     298         from bhmm.estimators._tmatrix_disconnected import estimate_P, stationary_distribution
#     299         T = estimate_P(C, reversible=self._hmm.is_reversible, fixed_statdist=self._fixed_stationary_distribution,
# --> 300                        maxiter=maxiter, maxerr=1e-12, mincount_connectivity=1e-16)
#     301         # print 'P:\n', T
#     302         # estimate stationary or init distribution
#
# /Users/robert_arbon/anaconda/lib/python2.7/site-packages/bhmm/estimators/_tmatrix_disconnected.pyc in estimate_P(C, reversible, fixed_statdist, maxiter, maxerr, mincount_connectivity)
#      81             mask[s] = True
#      82             if C[np.ix_(mask, ~mask)].sum() > 0:  # outgoing transitions - use partial rev algo.
# ---> 83                 transition_matrix_partial_rev(C, P, mask, maxiter=maxiter, maxerr=maxerr)
#      84             else:  # closed set - use standard estimator
#      85                 I = np.ix_(mask, mask)
#
# /Users/robert_arbon/anaconda/lib/python2.7/site-packages/bhmm/estimators/_tmatrix_disconnected.pyc in transition_matrix_partial_rev(C, P, S, maxiter, maxerr)
#     164         rowsums_new = X.sum(axis=1) + Y.sum(axis=1)
#     165         # compute error
# --> 166         err = np.max(np.abs(rowsums_new - rowsums))
#     167         # update
#     168         rowsums = rowsums_new
#
# /Users/robert_arbon/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in amax(a, axis, out, keepdims)
#    2295     else:
#    2296         return _methods._amax(a, axis=axis,
# -> 2297                             out=out, **kwargs)
#    2298
#    2299
#
# /Users/robert_arbon/anaconda/lib/python2.7/site-packages/numpy/core/_methods.pyc in _amax(a, axis, out, keepdims)
#      24 # small reductions
#      25 def _amax(a, axis=None, out=None, keepdims=False):
# ---> 26     return umr_maximum(a, axis, None, out, keepdims)
#      27
#      28 def _amin(a, axis=None, out=None, keepdims=False):
#
# KeyboardInterrupt:
