# %%
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %%
import mdtraj as md
from sklearn.pipeline import Pipeline
from msmbuilder.io import load_trajs, load_meta, preload_tops, load_generic
from msmbuilder.feature_extraction import DihedralFeaturizer
from msmbuilder.feature_selection import VarianceThreshold
from msmbuilder.preprocessing import RobustScaler
from msmbuilder.decomposition import tICA
import numpy as np

# %% [markdown]
# ## Load data

# %%
def get_timings(meta):
    frames_tot = meta['nframes'].sum()
    n_frames = meta['nframes'].unique()
    assert (len(n_frames) == 1, 'Different trajectory lengths')
    n_frames = n_frames[0]
    dt = meta['step_ps'][0]
    to_ns = dt/1000
    t_max = n_frames*to_ns
    return to_ns, t_max, frames_tot


def traj_load(irow):
    i, row = irow
    traj = md.load(row['traj_fn'], top=tops[row['top_fn']])
    return i, traj
# Out:
# <ipython-input-3-b7f0c528c48c>:4: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert (len(n_frames) == 1, 'Different trajectory lengths')

# %%
meta = load_meta('meta.pandas.pickl')
tops = preload_tops(meta)
trajs = [md.load(row['traj_fn'], top=tops[row['top_fn']], stride=1) 
         for i, row in meta.iterrows()]

# %% [markdown]
# ## Get internal coordinates

# %%
bonds = load_generic('proc_traj/2agy_as-1_bonds.pickl')
angles = load_generic('proc_traj/2agy_as-1_angles.pickl')
dihedrals = load_generic('proc_traj/2agy_as-1_dihedrals.pickl')

# %% [markdown]
# ## Set up the estimators for the pipeline

# %%
def compute_dihedrals(traj, indices):
    dihedrals = md.compute_dihedrals(traj, indices=indices)
    dihedrals = np.concatenate((np.cos(dihedrals), np.sin(dihedrals)), axis=1)
    return dihedrals

def compute_angles(traj, indices):
    angles = md.compute_angles(traj, angle_indices=indices)
    angles = np.concatenate((np.cos(angles), np.sin(angles)), axis=1)
    return angles

# %%
to_ns, t_max, frames_tot = get_timings(meta)

# %%
from msmbuilder.feature_extraction import FunctionFeaturizer, AtomPairsFeaturizer
from msmbuilder.feature_selection import FeatureSelector
from msmbuilder.cluster import LandmarkAgglomerative, MiniBatchKMeans
from msmbuilder.msm import MarkovStateModel

dihedrals_feat = FunctionFeaturizer(compute_dihedrals, func_args={'indices': dihedrals})
angles_feat = FunctionFeaturizer(compute_angles, func_args={'indices': angles})
bonds_feat = AtomPairsFeaturizer(pair_indices=bonds, periodic=True)

features = FeatureSelector([('bonds', bonds_feat), ('angles', angles_feat), ('dihedrals', dihedrals_feat)], 
                         which_feat=['bonds', 'angles', 'dihedrals'])

n_clusters = int(np.sqrt(frames_tot))
clusterer = LandmarkAgglomerative(n_clusters=n_clusters,
                                  n_landmarks=n_clusters//10,
                                  linkage='ward', metric='euclidean',
                                  landmark_strategy='stride',
                                  random_state=None, max_landmarks=None,
                                  ward_predictor='ward')
clusterer = MiniBatchKMeans(n_clusters = n_clusters)

# %%
estimators = [('features', features), ('variance', VarianceThreshold()),
              ('scaling', RobustScaler()), ('tICA', tICA(lag_time=int(30/to_ns), n_components=3)), 
             ('cluster',  clusterer)]
pipe = Pipeline(estimators)

# %%
ctraj = pipe.fit_transform(trajs)

# %% [markdown]
# ## Run MSM for different lags

# %%
from sklearn.model_selection import train_test_split

# train, test = train_test_split(ftrajs, test_size=0.4, random_state=42)
to_ns, t_max, frames_tot = get_timings(meta)

start_lag = int(1/to_ns)
stop_lag = int(81/to_ns)
n_lags = 71
lags = np.linspace(start_lag, stop_lag, n_lags, dtype=int)
print(lags)

msm_timescales = 10
eigenvalues = np.zeros((lags.shape[0], msm_timescales))
# Run loop
for idx, lag in enumerate(lags): 
    msm = MarkovStateModel(lag_time=lag, n_timescales=msm_timescales)
    print('{}, '.format(lag), end='')
    msm.fit(ctraj)
    eigenvalues[idx] = msm.eigenvalues_[1:]
# Out:
# [ 100  214  328  442  557  671  785  900 1014 1128 1242 1357 1471 1585 1700
#  1814 1928 2042 2157 2271 2385 2500 2614 2728 2842 2957 3071 3185 3300 3414
#  3528 3642 3757 3871 3985 4100 4214 4328 4442 4557 4671 4785 4900 5014 5128
#  5242 5357 5471 5585 5700 5814 5928 6042 6157 6271 6385 6500 6614 6728 6842
#  6957 7071 7185 7300 7414 7528 7642 7757 7871 7985 8100]
# 100, MSM contains 2 strongly connected components above weight=0.01. Component 1 selected, with population 51.070176%
# 214, MSM contains 2 strongly connected components above weight=0.00. Component 1 selected, with population 51.073703%
# 328, MSM contains 2 strongly connected components above weight=0.00. Component 1 selected, with population 51.077313%
# 442, MSM contains 2 strongly connected components above weight=0.00. Component 1 selected, with population 51.081010%
# 557, MSM contains 2 strongly connected components above weight=0.00. Component 1 selected, with population 51.084831%
# 671, MSM contains 2 strongly connected components above weight=0.00. Component 1 selected, with population 51.088712%
# 785, MSM contains 2 strongly connected components above weight=0.00. Component 1 selected, with population 51.092689%
# 900, MSM contains 2 strongly connected components above weight=0.00. Component 1 selected, with population 51.096803%
# 1014, MSM contains 2 strongly connected components above weight=0.00. Component 1 selected, with population 51.100986%
# 1128, MSM contains 2 strongly connected components above weight=0.00. Component 1 selected, with population 51.105277%
# 1242, MSM contains 2 strongly connected components above weight=0.00. Component 1 selected, with population 51.109681%
# 1357, MSM contains 4 strongly connected components above weight=0.00. Component 3 selected, with population 51.114241%
# 1471, MSM contains 4 strongly connected components above weight=0.00. Component 3 selected, with population 51.118885%
# 1585, MSM contains 4 strongly connected components above weight=0.00. Component 3 selected, with population 51.123654%
# 1700, MSM contains 4 strongly connected components above weight=0.00. Component 3 selected, with population 51.128600%
# 1814, MSM contains 4 strongly connected components above weight=0.00. Component 3 selected, with population 51.133640%
# 1928, MSM contains 4 strongly connected components above weight=0.00. Component 3 selected, with population 51.138824%
# 2042, MSM contains 4 strongly connected components above weight=0.00. Component 3 selected, with population 51.144158%
# 2157, MSM contains 4 strongly connected components above weight=0.00. Component 3 selected, with population 51.149697%
# 2271, MSM contains 4 strongly connected components above weight=0.00. Component 3 selected, with population 51.155351%
# 2385, MSM contains 4 strongly connected components above weight=0.00. Component 3 selected, with population 51.161176%
# 2500, MSM contains 4 strongly connected components above weight=0.00. Component 3 selected, with population 51.167233%
# 2614, MSM contains 4 strongly connected components above weight=0.00. Component 3 selected, with population 51.173425%
# 2728, MSM contains 4 strongly connected components above weight=0.00. Component 3 selected, with population 51.179813%
# 2842, MSM contains 4 strongly connected components above weight=0.00. Component 3 selected, with population 51.186405%
# 2957, MSM contains 4 strongly connected components above weight=0.00. Component 3 selected, with population 51.193274%
# 3071, MSM contains 4 strongly connected components above weight=0.00. Component 3 selected, with population 51.200310%
# 3185, MSM contains 4 strongly connected components above weight=0.00. Component 3 selected, with population 51.207583%
# 3300, MSM contains 4 strongly connected components above weight=0.00. Component 3 selected, with population 51.215173%
# 3414, MSM contains 4 strongly connected components above weight=0.00. Component 3 selected, with population 51.222961%
# 3528, MSM contains 4 strongly connected components above weight=0.00. Component 3 selected, with population 51.231026%
# 3642, MSM contains 4 strongly connected components above weight=0.00. Component 3 selected, with population 51.239383%
# 3757, MSM contains 4 strongly connected components above weight=0.00. Component 3 selected, with population 51.248125%
# 3871, MSM contains 4 strongly connected components above weight=0.00. Component 3 selected, with population 51.257118%
# 3985, MSM contains 4 strongly connected components above weight=0.00. Component 3 selected, with population 51.266455%
# 4100, MSM contains 4 strongly connected components above weight=0.00. Component 3 selected, with population 51.276244%
# 4214, MSM contains 5 strongly connected components above weight=0.00. Component 4 selected, with population 51.266459%
# 4328, MSM contains 5 strongly connected components above weight=0.00. Component 4 selected, with population 51.276556%
# 4442, MSM contains 5 strongly connected components above weight=0.00. Component 4 selected, with population 51.287072%
# 4557, MSM contains 5 strongly connected components above weight=0.00. Component 4 selected, with population 51.298132%
# 4671, MSM contains 5 strongly connected components above weight=0.00. Component 4 selected, with population 51.309571%
# 4785, MSM contains 5 strongly connected components above weight=0.00. Component 4 selected, with population 51.321517%
# 4900, MSM contains 6 strongly connected components above weight=0.00. Component 5 selected, with population 51.318247%
# 5014, MSM contains 6 strongly connected components above weight=0.00. Component 5 selected, with population 51.330948%
# 5128, MSM contains 7 strongly connected components above weight=0.00. Component 6 selected, with population 51.246452%
# 5242, MSM contains 6 strongly connected components above weight=0.00. Component 5 selected, with population 51.358527%
# 5357, MSM contains 6 strongly connected components above weight=0.00. Component 5 selected, with population 51.373308%
# 5471, MSM contains 7 strongly connected components above weight=0.00. Component 6 selected, with population 51.284098%
# 5585, MSM contains 6 strongly connected components above weight=0.00. Component 5 selected, with population 51.405275%
# 5700, MSM contains 6 strongly connected components above weight=0.00. Component 5 selected, with population 51.422882%
# 5814, MSM contains 6 strongly connected components above weight=0.00. Component 5 selected, with population 51.440935%
# 5928, MSM contains 6 strongly connected components above weight=0.00. Component 5 selected, with population 51.460397%
# 6042, MSM contains 6 strongly connected components above weight=0.00. Component 5 selected, with population 51.480996%
# 6157, MSM contains 6 strongly connected components above weight=0.00. Component 5 selected, with population 51.503437%
# 6271, MSM contains 6 strongly connected components above weight=0.00. Component 5 selected, with population 51.514733%
# 6385, MSM contains 6 strongly connected components above weight=0.00. Component 5 selected, with population 51.513658%
# 6500, MSM contains 8 strongly connected components above weight=0.00. Component 7 selected, with population 51.377679%
# 6614, MSM contains 10 strongly connected components above weight=0.00. Component 9 selected, with population 51.265782%
# 6728, MSM contains 15 strongly connected components above weight=0.00. Component 14 selected, with population 50.577342%
# 6842, MSM contains 15 strongly connected components above weight=0.00. Component 14 selected, with population 50.556127%
# 6957, MSM contains 17 strongly connected components above weight=0.00. Component 16 selected, with population 50.191526%
# 7071, MSM contains 17 strongly connected components above weight=0.00. Component 16 selected, with population 50.243791%
# 7185, MSM contains 17 strongly connected components above weight=0.00. Component 16 selected, with population 50.179840%
# 7300, MSM contains 17 strongly connected components above weight=0.00. Component 16 selected, with population 50.241319%
# 7414, MSM contains 21 strongly connected components above weight=0.00. Component 20 selected, with population 49.640492%
# 7528, MSM contains 21 strongly connected components above weight=0.00. Component 20 selected, with population 49.661206%
# 7642, MSM contains 22 strongly connected components above weight=0.00. Component 21 selected, with population 49.564647%
# 7757, MSM contains 22 strongly connected components above weight=0.00. Component 21 selected, with population 49.579943%
# 7871, MSM contains 23 strongly connected components above weight=0.00. Component 22 selected, with population 49.451033%
# 7985, MSM contains 24 strongly connected components above weight=0.00. Component 23 selected, with population 49.457196%
# 8100, MSM contains 24 strongly connected components above weight=0.00. Component 23 selected, with population 49.462171%

# %% [markdown]
# ## Plot eigenvalues

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

sns.set_palette('Blues_r', 168)
sns.set_style('white')
for idx in range(msm_timescales):
    plt.plot(lags*to_ns, eigenvalues.T[idx])
plt.xlabel('Time lag (ns)')
plt.ylabel('Eigenvalues')

# %% [markdown]
# ## Plot timescales

# %%
timescales = eigenvalues*lags[:, np.newaxis]*to_ns

sns.set_palette('Blues_r', 168)
sns.set_style('white')
for idx in range(msm_timescales):
    plt.plot(lags*to_ns, timescales.T[idx])
plt.xlabel('Time lag (ns)')
plt.ylabel('Eigenvalues')
